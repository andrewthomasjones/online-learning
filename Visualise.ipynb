# %%
# %load_ext google.cloud.bigquery
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors
plt.style.use('seaborn-whitegrid')
import numpy as np
import seaborn as sns

# %%
project_id = "sandbox-vm-252402"
dataset_id = "stream_test"
table_id = "table1"

# %%
# %%bigquery data
# SELECT *
# FROM `sandbox-vm-252402.stream_test.table1`

# %%
print(data.head())
x1,x2=[5,-5]
y1,y2=[-10,10]
# Out:
#           x         y class
# 0  2.607408  4.489597     A
# 1 -1.022959 -0.054139     B
# 2  2.368607  0.038242     A
# 3 -1.693865 -2.606834     B
# 4  1.243429  3.390694     A

# %%
g = sns.scatterplot(x="x", y="y",
              hue="class",
              data=data);
g.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
plt.plot([x1, x2], [y1, y2], linewidth=1.5, c='r');
plt.ylim((-5,5));
plt.xlim((-5,5));
